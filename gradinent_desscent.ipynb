# %%
import matplotlib.pyplot as plt
import numpy as np
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score, mean_squared_error

# %%
#i'll set x and y values
np.random.seed(42)

n = 30
X = np.random.rand(n)
y = 2 + 3*X + np.random.normal(0, 0.5, n)

# %%
plt.scatter(X, y);

# %%
def mse(X, w1, w0, y): # let's define MSE func
    y_pred = w1 * X + w0
    return np.sum((y - y_pred) ** 2) / len(y_pred)

# %%
slope = 2.880892192391606
intercept = 2.051878603971828
y_calc = slope * X + intercept

# %%
# define parameters
E = 0.0001
w1 = 0
w0 = 0
learning_rate = 0.1

next_w1 = w1
next_w0 = w0
k=0

while True:
    k += 1
    cur_w1 = next_w1
    cur_w0 = next_w0
    y_pred = cur_w1 * X + cur_w0

    next_w0 = cur_w0 - learning_rate * (2/len(X)*np.sum((y - y_pred)) * (-1)) # for intercept
    next_w1 = cur_w1 - learning_rate * (2/len(X)*np.sum((y - y_pred) * (-X))) # for slope

    print(f"We stopped at {k} iteration and got MSE = {mse(X, cur_w1, cur_w0, y)}")
    slope =
    if (abs(cur_w1 - next_w1) <= E) and (abs(cur_w0 - next_w0) <= E):
        break
# Out:
# We stopped at 1 iteration and got MSE = 10.976167088542853
# We stopped at 2 iteration and got MSE = 6.426166417146825
# We stopped at 3 iteration and got MSE = 3.804851208383482
# We stopped at 4 iteration and got MSE = 2.294337788548194
# We stopped at 5 iteration and got MSE = 1.4235851161301092
# We stopped at 6 iteration and got MSE = 0.92130786135804
# We stopped at 7 iteration and got MSE = 0.6312652207158574
# We stopped at 8 iteration and got MSE = 0.46347354043823014
# We stopped at 9 iteration and got MSE = 0.36610839645146387
# We stopped at 10 iteration and got MSE = 0.30932227069091833
# We stopped at 11 iteration and got MSE = 0.2759247294593658
# We stopped at 12 iteration and got MSE = 0.256014895301615
# We stopped at 13 iteration and got MSE = 0.2438901475735446
# We stopped at 14 iteration and got MSE = 0.23626576235823407
# We stopped at 15 iteration and got MSE = 0.23124955647417816
# We stopped at 16 iteration and got MSE = 0.22775135799493793
# ...
